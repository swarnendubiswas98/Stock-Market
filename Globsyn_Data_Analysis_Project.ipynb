# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#for avoid warnings
import warnings
warnings.filterwarnings('ignore')

# %%
Stock_analysis1=pd.read_csv("C:/Globsyn/selected/AAPL_data.csv",parse_dates=True, index_col=0)

# %%
Stock_analysis1
# Out:
#                 open      high       low     close     volume  Name
# date
# 2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# 2013-02-15   66.9785   67.1656   65.7028   65.7371   97924631  AAPL
# 2013-02-19   65.8714   66.1042   64.8356   65.7128  108854046  AAPL
# 2013-02-20   65.3842   65.3842   64.1142   64.1214  118891367  AAPL
# 2013-02-21   63.7142   64.1671   63.2599   63.7228  111596821  AAPL
# 2013-02-22   64.1785   64.5142   63.7999   64.4014   82583823  AAPL
# 2013-02-25   64.8356   65.0171   63.2242   63.2571   92899597  AAPL
# 2013-02-26   63.4028   64.5056   62.5228   64.1385  125096657  AAPL
# 2013-02-27   64.0614   64.6342   62.9499   63.5099  146674682  AAPL
# ...

# %%
Stock_analysis2=pd.read_csv("C:/Globsyn/selected/AMZN_data.csv",parse_dates=True, index_col=0)

# %%
Stock_analysis2
# Out:
#                open      high        low     close    volume  Name
# date
# 2013-02-08   261.40   265.250   260.5550   261.950   3879078  AMZN
# 2013-02-11   263.20   263.250   256.6000   257.210   3403403  AMZN
# 2013-02-12   259.19   260.160   257.0000   258.700   2938660  AMZN
# 2013-02-13   261.53   269.960   260.3000   269.470   5292996  AMZN
# 2013-02-14   267.37   270.650   265.4000   269.240   3462780  AMZN
# 2013-02-15   267.63   268.920   263.1100   265.090   3979832  AMZN
# 2013-02-19   265.91   270.110   264.5000   269.750   2853752  AMZN
# 2013-02-20   270.20   274.300   266.3710   266.410   3528862  AMZN
# 2013-02-21   265.12   269.480   263.2500   265.940   3637396  AMZN
# 2013-02-22   266.62   267.110   261.6100   265.420   3123402  AMZN
# 2013-02-25   266.94   268.694   259.6500   259.870   3032109  AMZN
# 2013-02-26   260.89   262.040   255.7300   259.360   3348011  AMZN
# 2013-02-27   259.40   265.830   256.8600   263.250   2908010  AMZN
# ...

# %%
Stock_analysis3=pd.read_csv("C:/Globsyn/selected/GOOGL_data.csv",parse_dates=True, index_col=0)

# %%
Stock_analysis3
# Out:
#                  open       high        low      close   volume   Name
# date
# 2013-02-08   390.4551   393.7283   390.1698   393.0777  6031199  GOOGL
# 2013-02-11   389.5892   391.8915   387.2619   391.6012  4330781  GOOGL
# 2013-02-12   391.2659   394.3440   390.0747   390.7403  3714176  GOOGL
# 2013-02-13   390.4551   393.0677   390.3750   391.8214  2393946  GOOGL
# 2013-02-14   390.2549   394.7644   389.2739   394.3039  3466971  GOOGL
# 2013-02-15   394.0937   397.0266   393.9285   396.8414  5453980  GOOGL
# 2013-02-19   398.3930   403.9035   398.0376   403.8284  5857528  GOOGL
# 2013-02-20   403.0527   404.8895   396.2929   396.6262  5522500  GOOGL
# 2013-02-21   399.3990   403.1277   396.0056   398.1628  7008464  GOOGL
# 2013-02-22   400.0296   401.0256   397.2969   400.2549  4103315  GOOGL
# 2013-02-25   401.5512   404.6092   395.6402   395.7804  4602925  GOOGL
# 2013-02-26   397.8975   398.3729   392.5922   395.4601  4399988  GOOGL
# ...

# %%
Stock_analysis4=pd.read_csv("C:/Globsyn/selected/MSFT_data.csv",parse_dates=True, index_col=0)

# %%
Stock_analysis4 #volume=how many shares have been traded(cp+sp)
# Out:
#                open     high      low   close    volume  Name
# date
# 2013-02-08  27.3500  27.7100  27.3100  27.550  33318306  MSFT
# 2013-02-11  27.6500  27.9200  27.5000  27.860  32247549  MSFT
# 2013-02-12  27.8800  28.0000  27.7500  27.880  35990829  MSFT
# 2013-02-13  27.9300  28.1100  27.8800  28.030  41715530  MSFT
# 2013-02-14  27.9200  28.0600  27.8700  28.040  32663174  MSFT
# 2013-02-15  28.0400  28.1600  27.8750  28.010  49650538  MSFT
# 2013-02-19  27.8801  28.0900  27.8000  28.045  38804616  MSFT
# 2013-02-20  28.1300  28.2000  27.8300  27.870  44109412  MSFT
# 2013-02-21  27.7400  27.7400  27.2300  27.490  49078338  MSFT
# 2013-02-22  27.6800  27.7600  27.4800  27.760  31425726  MSFT
# 2013-02-25  27.9700  28.0500  27.3700  27.370  48011248  MSFT
# 2013-02-26  27.3800  27.6000  27.3400  27.370  49917353  MSFT
# 2013-02-27  27.4200  28.0000  27.3300  27.810  36390889  MSFT
# 2013-02-28  27.8800  27.9700  27.7400  27.800  35836861  MSFT
# ...

# %%
Stock_analysis1[:1]
# Out:
#                open     high      low    close     volume  Name
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL

# %%
Stock_analysis4[Stock_analysis4['close']>=27.35]
# Out:
#                open     high      low   close    volume  Name
# date
# 2013-02-08  27.3500  27.7100  27.3100  27.550  33318306  MSFT
# 2013-02-11  27.6500  27.9200  27.5000  27.860  32247549  MSFT
# 2013-02-12  27.8800  28.0000  27.7500  27.880  35990829  MSFT
# 2013-02-13  27.9300  28.1100  27.8800  28.030  41715530  MSFT
# 2013-02-14  27.9200  28.0600  27.8700  28.040  32663174  MSFT
# 2013-02-15  28.0400  28.1600  27.8750  28.010  49650538  MSFT
# 2013-02-19  27.8801  28.0900  27.8000  28.045  38804616  MSFT
# 2013-02-20  28.1300  28.2000  27.8300  27.870  44109412  MSFT
# 2013-02-21  27.7400  27.7400  27.2300  27.490  49078338  MSFT
# 2013-02-22  27.6800  27.7600  27.4800  27.760  31425726  MSFT
# 2013-02-25  27.9700  28.0500  27.3700  27.370  48011248  MSFT
# 2013-02-26  27.3800  27.6000  27.3400  27.370  49917353  MSFT
# 2013-02-27  27.4200  28.0000  27.3300  27.810  36390889  MSFT
# 2013-02-28  27.8800  27.9700  27.7400  27.800  35836861  MSFT
# ...

# %%
Stock_analysis4.isnull().sum()
# Out:
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
close=pd.DataFrame({"AAPL":Stock_analysis1["close"],
                    "AMZN":Stock_analysis2["close"],
                   "GOOGL":Stock_analysis3["close"],
                   "MSFT": Stock_analysis4["close"]})

# %%
close
# Out:
#                 AAPL      AMZN      GOOGL    MSFT
# date
# 2013-02-08   67.8542   261.950   393.0777  27.550
# 2013-02-11   68.5614   257.210   391.6012  27.860
# 2013-02-12   66.8428   258.700   390.7403  27.880
# 2013-02-13   66.7156   269.470   391.8214  28.030
# 2013-02-14   66.6556   269.240   394.3039  28.040
# 2013-02-15   65.7371   265.090   396.8414  28.010
# 2013-02-19   65.7128   269.750   403.8284  28.045
# 2013-02-20   64.1214   266.410   396.6262  27.870
# 2013-02-21   63.7228   265.940   398.1628  27.490
# 2013-02-22   64.4014   265.420   400.2549  27.760
# 2013-02-25   63.2571   259.870   395.7804  27.370
# 2013-02-26   64.1385   259.360   395.4601  27.370
# 2013-02-27   63.5099   263.250   400.2899  27.810
# 2013-02-28   63.0571   264.270   401.0006  27.800
# 2013-03-01   61.4957   265.740   403.4981  27.950
# 2013-03-04   60.0071   273.110   411.1628  28.150
# 2013-03-05   61.5919   275.590   419.7213  28.350
# 2013-03-06   60.8088   273.790   416.1057  28.090
# ...

# %%
a=close.corr(method='pearson', min_periods=1)

# %%
sns.heatmap(a,annot=True)

# %%
#plt.imshow(close, cmap='hot', interpolation='none')
#plt.colorbar()
#plt.xticks(range(len(close)), close.columns)
#plt.yticks(range(len(close)), close.columns)
#plt.gcf().set_size_inches(30,20)

# %%
a.plot(grid =True , figsize=(20,10))
plt.title("Correlation")
plt.show()

# %%
close.plot(grid =True , figsize=(20,10))
plt.title("Correlation")
plt.show()

# %%
#names=["AAPL","AMZN","GOOGL","MSFT"]
#fig = plt.figure()
#ax = fig.add_subplot(111)
#cax = ax.matshow(a, vmin=-1, vmax=1)
#fig.colorbar(cax)
#ticks = np.arange(0,9,1)
#ax.set_xticks(ticks)
#ax.set_yticks(ticks)
#ax.set_xticklabels(names)
#ax.set_yticklabels(names)
#plt.figimage(20)
#plt.gcf().set_size_inches(10,20)
#plt.show()

# %%
#corr = data.corr()
#fig = plt.figure()
#ax = fig.add_subplot(111)
#cax = ax.matshow(a,cmap='jet', vmin=-1, vmax=1)
#fig.colorbar(cax)
#ticks = np.arange(0,len(close.columns),1)
#ax.set_xticks(ticks)
#plt.xticks(rotation=90)
#ax.set_yticks(ticks)
#ax.set_xticklabels(close.columns)
#ax.set_yticklabels(close.columns)
#plt.gcf().set_size_inches(10,10)
#plt.show()
from matplotlib.offsetbox import AnchoredText

# %%
Stock_analysis4["MA50"]=Stock_analysis4["close"].rolling(50).mean()
Stock_analysis4["MA100"]=Stock_analysis4["close"].rolling(100).mean()

# %%
Stock_analysis1["MA50"]=Stock_analysis1["close"].rolling(50).mean()
Stock_analysis1["MA100"]=Stock_analysis1["close"].rolling(100).mean()

# %%
Stock_analysis4["MA50"]=Stock_analysis4["close"].rolling(50).mean()
Stock_analysis4["MA100"]=Stock_analysis4["close"].rolling(100).mean()

Stock_analysis4[["close","MA50","MA100"]].plot(label="MSFT",figsize=(16,8))
plt.title("MOVING AVERAGE")
#plt.plot(label="Amd")


#add_titlebox(plt, 'Histogram: home age')
#plt.text(1, 1, 'Brackmard minimum')
ax = plt.gca()
#text(0.1, 0.9,'matplotlib', ha='center', va='center', transform=ax.transAxes)
ax.set_ylabel('90d moving average: CBOE VIX',fontsize=20)
plt.grid()
Stock_analysis1["MA50"]=Stock_analysis1["close"].rolling(50).mean()
Stock_analysis1["MA100"]=Stock_analysis1["close"].rolling(100).mean()
Stock_analysis1[["close","MA50","MA100"]].plot(figsize=(16,8))

#Stock_analysis4["date"].plot()
#Stock_analysis4["date"].plot()
plt.grid()
#xlim(["date"])
plt.show()

# %%
Stock_analysis4[50:51]
